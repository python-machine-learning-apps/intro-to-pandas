# %% [markdown]
# # Let's practice reading in datasets

# %% [markdown]
# ### What's an import?
# To use any package in your code, you must first make it accessible. You have to import it. You can't use anything in Python before it is defined. Some things are built in, for example the basic types (like int, float, etc) can be used whenever you want. But most things you will want to do will need a little more than that. Importing a package (like pandas) makes it accessible in the current scope. Since we used Anaconda to obtain python, we have already installed many of the most popular packages (like `numpy` and `pandas`) and we just have to use `import` to activate them for this session.

# %%
# Let's import the pandas package.
import pandas as pd

# %% [markdown]
# ## Practice reading data files into pandas

# %%
# Try this out:
df=pd.read_csv('../data/flags.csv')

# %%
# Look at the first few lines of data:
df.head()
# Out:
#              name  landmass  zone  area  population  language  religion  bars  \
# 0     Afghanistan         5     1   648          16        10         2     0
# 1         Albania         3     1    29           3         6         6     0
# 2         Algeria         4     1  2388          20         8         2     2
# 3  American-Samoa         6     3     0           0         1         1     0
# 4         Andorra         3     1     0           0         6         0     3
#
#    stripes  colors  ...  saltires  quarters  sunstars  crescent  triangle  \
# 0        3       5  ...         0         0         1         0         0
# 1        0       3  ...         0         0         1         0         0
# 2        0       3  ...         0         0         1         1         0
# 3        0       5  ...         0         0         0         0         1
# 4        0       3  ...         0         0         0         0         0
#
#    icon  animate text  topleft  botright
# 0     1        0    0    black     green
# 1     0        1    0      red       red
# 2     0        0    0    green     white
# 3     1        1    0     blue       red
# 4     0        0    0     blue       red
#
# [5 rows x 30 columns]

# %%
# And the last few:
df.tail()
# Out:
#               name  landmass  zone  area  population  language  religion  \
# 189  Western-Samoa         6     3     3           0         1         1
# 190     Yugoslavia         3     1   256          22         6         6
# 191          Zaire         4     2   905          28        10         5
# 192         Zambia         4     2   753           6        10         5
# 193       Zimbabwe         4     2   391           8        10         5
#
#      bars  stripes  colors  ...  saltires  quarters  sunstars  crescent  \
# 189     0        0       3  ...         0         1         5         0
# 190     0        3       4  ...         0         0         1         0
# 191     0        0       4  ...         0         0         0         0
# 192     3        0       4  ...         0         0         0         0
# 193     0        7       5  ...         0         0         1         0
#
#      triangle  icon  animate text  topleft  botright
# 189         0     0        0    0     blue       red
# 190         0     0        0    0     blue       red
# 191         0     1        1    0    green     green
# 192         0     0        1    0    green     brown
# 193         1     1        1    0    green     green
#
# [5 rows x 30 columns]

# %%
# Show a random selection of rows:
df.sample()
# Out:
#         name  landmass  zone  area  population  language  religion  bars  \
# 9  Argentine         2     3  2777          28         2         0     0
#
#    stripes  colors  ...  saltires  quarters  sunstars  crescent  triangle  \
# 9        3       3  ...         0         0         1         0         0
#
#    icon  animate text  topleft  botright
# 9     0        0    0     blue      blue
#
# [1 rows x 30 columns]

# %%
# How big is my dataset?
df.shape
# Out:
# (194, 30)

# %%
# What are the columns?
df.columns
# Out:
# Index(['name', 'landmass', 'zone', 'area', 'population', 'language',
#        'religion', 'bars', 'stripes', 'colors', 'red', 'green', 'blue', 'gold',
#        'white', 'black', 'orange', 'mainhue', 'circles', 'crosses', 'saltires',
#        'quarters', 'sunstars', 'crescent', 'triangle', 'icon', 'animate',
#        'text', 'topleft', 'botright'],
#       dtype='object')

# %%
# What type of object is this?
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Show me some high-level statistics about my dataframe.
results=df.describe()
results
# Out:
#          landmass        zone          area   population    language  \
# count  194.000000  194.000000    194.000000   194.000000  194.000000
# mean     3.572165    2.211340    700.046392    23.268041    5.340206
# std      1.553018    1.308274   2170.927932    91.934085    3.496517
# min      1.000000    1.000000      0.000000     0.000000    1.000000
# 25%      3.000000    1.000000      9.000000     0.000000    2.000000
# 50%      4.000000    2.000000    111.000000     4.000000    6.000000
# 75%      5.000000    4.000000    471.250000    14.000000    9.000000
# max      6.000000    4.000000  22402.000000  1008.000000   10.000000
#
#          religion        bars     stripes      colors         red  ...  \
# count  194.000000  194.000000  194.000000  194.000000  194.000000  ...
# mean     2.190722    0.453608    1.551546    3.463918    0.788660  ...
# std      2.061167    1.038339    2.328005    1.300154    0.409315  ...
# min      0.000000    0.000000    0.000000    1.000000    0.000000  ...
# 25%      1.000000    0.000000    0.000000    3.000000    1.000000  ...
# 50%      1.000000    0.000000    0.000000    3.000000    1.000000  ...
# 75%      4.000000    0.000000    3.000000    4.000000    1.000000  ...
# max      7.000000    5.000000   14.000000    8.000000    1.000000  ...
#
#           circles     crosses    saltires    quarters    sunstars    crescent  \
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean     0.170103    0.149485    0.092784    0.149485    1.386598    0.056701
# std      0.463075    0.385387    0.290879    0.435860    4.396186    0.231869
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    1.000000    0.000000
# max      4.000000    2.000000    1.000000    4.000000   50.000000    1.000000
#
#          triangle        icon     animate        text
# count  194.000000  194.000000  194.000000  194.000000
# mean     0.139175    0.252577    0.201031    0.082474
# std      0.347025    0.435615    0.401808    0.275798
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.750000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Now try this with a few other data files from the datasets folder.

# %%
# try another csv file:
df1=pd.read_csv('../data/country-codes.csv', usecols=[0,2], header=0, encoding = "ISO-8859-1")
df1.head()
# Out:
#           Country Alpha-3 code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
# try a tsv file:
df2=pd.read_csv("../data/eu-govt-bonds.tsv", sep="\t")
df2.head()
# Out:
#   int_rt,geo\time 2019M02  2019M03  2019M04  2019M05  2019M06  2019M07   \
# 0         MCBY,AT    0.45     0.38     0.31     0.24     0.03    -0.10
# 1         MCBY,BE    0.69     0.54     0.47     0.41     0.15     0.00
# 2         MCBY,BG    0.68     0.67     0.50     0.48     0.32     0.43
# 3         MCBY,CY    2.00     1.74     1.49     1.34     0.82     0.66
# 4         MCBY,CZ    1.76     1.82     1.82     1.86     1.58     1.36
#
#   2019M08  2019M09  2019M10  2019M11  2019M12  2020M01
# 0   -0.37    -0.30    -0.20    -0.09    -0.04    -0.09
# 1   -0.28    -0.24    -0.16    -0.04     0.01    -0.03
# 2    0.35     0.35     0.25     0.22     0.18     0.15
# 3    0.44     0.48     0.51     0.58     0.57     0.61
# 4    0.99     1.24     1.32     1.47     1.51     1.62

# %%
! conda install openpyxl -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/studio-lab-user/.conda/envs/default
#
#   added / updated specs:
#     - openpyxl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     et_xmlfile-1.0.1           |          py_1001          11 KB  conda-forge
#     openpyxl-3.0.9             |     pyhd8ed1ab_0         153 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         164 KB
#
# The following NEW packages will be INSTALLED:
#
#   et_xmlfile         conda-forge/noarch::et_xmlfile-1.0.1-py_1001
#   openpyxl           conda-forge/noarch::openpyxl-3.0.9-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# et_xmlfile-1.0.1     | 11 KB     | ##################################### | 100%
# openpyxl-3.0.9       | 153 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# try an excel file:
df3=pd.read_excel('../data/loans_data_dictionary.xlsx', sheet_name='rejections', header=0)
# pd.set_option("max_colwidth", 100)
df3
# Out:
#        RejectStats File                                        Description
# 0      Amount Requested         The total amount requested by the borrower
# 1      Application Date               The date which the borrower applied
# 2            Loan Title            The loan title provided by the borrower
# 3            Risk_Score  For applications prior to November 5, 2013 the...
# 4  Debt-To-Income Ratio  A ratio calculated using the borrower’s total ...
# 5                 State  The state provided by the borrower in the loan...
# 6     Employment Length  Employment length in years. Possible values ar...

# %%
# try a json file:
df4=pd.read_json('../data/yelp.json', lines=True)
df4.head()
# Out:
#                                   votes                 user_id  \
# 0  {'funny': 0, 'useful': 5, 'cool': 2}  rLtl8ZkDX5vH5nAx9C3q5Q
# 1  {'funny': 0, 'useful': 0, 'cool': 0}  0a2KyEL0d3Yb1V6aivbIuQ
# 2  {'funny': 0, 'useful': 1, 'cool': 0}  0hT2KtfLiobPvh6cDC8JQg
# 3  {'funny': 0, 'useful': 2, 'cool': 1}  uZetl9T0NcROGOyFfughhg
# 4  {'funny': 0, 'useful': 0, 'cool': 0}  vYmM4KTsC8ZfQBg-j5MWkw
#
#                 review_id  stars       date  \
# 0  fWKvX83p0-ka4JS3dc6E5A      5 2011-01-26
# 1  IjZ33sJrzXqU-0X6U8NwyA      5 2011-07-27
# 2  IESLBzqUCLdSzSqm0eCSxQ      4 2012-06-14
# 3  G-WvGaISbqqaMHlNnByodA      5 2010-05-27
# 4  1uJFq2r5QfJG_6ExMRCaGw      5 2012-01-05
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#               business_id
# 0  9yKzy9PApeiPPOUJEtnvkg
# 1  ZRJwVLyzEJq1VAihDhYiow
# 2  6oRAC4uyJCsJl1X0WZpVSA
# 3  _1QQZuf4zZOyFCvXc0o6Vg
# 4  6ozycU1RpktNG2-1BroVtw

# %%
# Open a file that's saved online
url='https://opendata.arcgis.com/datasets/2e65fc16edc3481989d2cc17e6f8c533_54.csv'
df5 = pd.read_csv(url)
df5.head()
# Out:
#            X          Y  OBJECTID  \
# 0 -77.051688  38.959925         1
# 1 -77.052620  38.943642         2
# 2 -77.011771  38.941708         3
# 3 -77.086853  38.939100         4
# 4 -77.004667  38.937767         5
#
#                                                 NAME  \
# 0      ROCK CREEK PARK NATURE CENTER AND PLANETARIUM
# 1                                    HILLWOOD MUSEUM
# 2                                  LINCOLN'S COTTAGE
# 3  AMERICAN UNIVERSITY MUSEUM AT THE KATZEN ARTS ...
# 4             THE SAINT JOHN PAUL II NATIONAL SHRINE
#
#                                    ALT_NAME  \
# 0                                       NaN
# 1       HILLWOOD ESTATE, MUSEUM AND GARDENS
# 2  ARMED FORCES RETIREMENT HOME BUILDING 12
# 3                AMERICAN UNIVERSITY MUSEUM
# 4                                       NaN
#
#                                                LABEL  \
# 0      Rock Creek Park Nature Center and Planetarium
# 1                                    Hillwood Museum
# 2                                  Lincoln's Cottage
# 3  American University Museum at the Katzen Arts ...
# 4             The Saint John Paul II National Shrine
#
#                     ADDRESS     XCOORD     YCOORD  LONGITUDE   LATITUDE  \
# 0       5200 GLOVER ROAD NW  395520.36  143557.89 -77.051686  38.959917
# 1    4155 LINNEAN AVENUE NW  395438.56  141750.35 -77.052617  38.943634
# 2        LINCOLN''S COTTAGE  398979.76  141534.42 -77.011768  38.941700
# 3   3500 NEBRASKA AVENUE NW  392470.36  141248.41 -77.086851  38.939092
# 4     3900 HAREWOOD ROAD NE  399595.57  141096.85 -77.004665  38.937759
#
#    MAR_ID      GIS_ID                                GLOBALID  CREATOR  \
# 0  308551  MuseumPt_1  {B54753A4-D08B-48C2-910A-909E869EEC8D}      NaN
# 1  284839  MuseumPt_2  {1DEC08B3-5911-473F-9BE6-92AC141BB6CE}      NaN
# 2  292871  MuseumPt_3  {44FD074D-7AC4-4953-A15F-EBA267A9A1A4}      NaN
# 3  223996  MuseumPt_4  {14F57F1A-D67C-4D1F-A4DD-01D7BFF5E4B4}      NaN
# 4  288031  MuseumPt_5  {6EEBABB9-F216-4D30-A1DF-4555F92F1ED8}      NaN
#
#    CREATED  EDITOR  EDITED
# 0      NaN     NaN     NaN
# 1      NaN     NaN     NaN
# 2      NaN     NaN     NaN
# 3      NaN     NaN     NaN
# 4      NaN     NaN     NaN

# %%
# How about a datafile that's saved on github?
url="https://raw.githubusercontent.com/austinlasseter/plotly_dash_tutorial/master/00%20resources/titanic.csv"
df5 = pd.read_csv(url, index_col=0)
df5.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare     Embarked
# 0         0       3    male  22.0   7.2500  Southampton
# 1         1       1  female  38.0  71.2833    Cherbourg
# 2         1       3  female  26.0   7.9250  Southampton
# 3         1       1  female  35.0  53.1000  Southampton
# 4         0       3    male  35.0   8.0500  Southampton

# %%
# open a tbl file
df6=pd.read_csv('../data/user.tbl', sep='|')
df6.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Save your results as a new csv file

# %%
# This will save to your current working directory.
results.to_csv('my_results.csv')

# %%
# read it back in.
pd.read_csv('my_results.csv', index_col=0)
